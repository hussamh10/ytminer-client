# %% [markdown]
# # ytminer - Help Download Pakistani News Videos
#
# This notebook downloads YouTube videos from Pakistani news channels as part of a research project.
#
# **How it works:**
# 1. Installs the download client
# 2. Fetches video IDs from the central server
# 3. Downloads videos and uploads them to the research server
# 4. Automatically handles rate limiting and bot detection
#
# **Just click Runtime > Run all and leave this tab open.**

# %%
# Install the client (takes ~30 seconds)
# !pip install -q ytminer-client

# %%
# Start downloading and uploading to the research server
# This will run until the Colab session ends (~12 hours)
# Videos are uploaded immediately after download, so nothing is lost if the session dies
# !ytminer-download \
    --server http://obelix.cs.uiowa.edu:8765 \
    --output /tmp/videos \
    --upload \
    --delay 20 \
    --jitter 10
